# %%
import requests
import json
import plotly.graph_objects as go
import networkx as nx
import nbformat

# %%
northwestern_data = requests.get("https://api.openalex.org/works?filter=institutions.id:I111979921")
northwestern_data = northwestern_data.json()

# %%
urls = []
for i in northwestern_data['results']:
    urls.append(i['id'])

urls = [url.replace("https://", "https://api.") for url in urls]
urls
# Out:
# ['https://api.openalex.org/W2115017507',
#  'https://api.openalex.org/W2128654538',
#  'https://api.openalex.org/W2101977779',
#  'https://api.openalex.org/W2001442493',
#  'https://api.openalex.org/W2074231493',
#  'https://api.openalex.org/W2122679534',
#  'https://api.openalex.org/W2112165279',
#  'https://api.openalex.org/W2092858957',
#  'https://api.openalex.org/W2004550299',
#  'https://api.openalex.org/W2163480486',
#  'https://api.openalex.org/W2052566608',
#  'https://api.openalex.org/W2051434435',
#  'https://api.openalex.org/W2002799357',
#  'https://api.openalex.org/W1973714168',
#  'https://api.openalex.org/W2170892587',
#  'https://api.openalex.org/W2029050771',
#  'https://api.openalex.org/W2116347131',
#  'https://api.openalex.org/W2133979383',
#  'https://api.openalex.org/W2121830147',
#  'https://api.openalex.org/W2142596047',
#  'https://api.openalex.org/W2108376819',
#  'https://api.openalex.org/W2141947008',
#  'https://api.openalex.org/W2142136198',
#  'https://api.openalex.org/W2009260120',
#  'https://api.openalex.org/W1977137834']

# %%
graph = {}

# %%
def get_data(url):
    response = requests.get(url)
    data = response.json()
    return data

# %%
def add_data_to_graph(graph, data):
    for authorship in data['authorships']:
        author = authorship['author']['display_name']
        graph[author] = []
        for other_authorship in data['authorships']:
            other_author = other_authorship['author']['display_name']
            if other_author != author:
                graph[author].append(other_author)

# %%
for i in range(len(urls)):
    data = get_data(urls[i])
    add_data_to_graph(graph, data)

# %%
graph
# Out:
# {'Guy M. McKhann': ['David S. Knopman',
#   'Howard Chertkow',
#   'Bradley T. Hyman',
#   'Clifford R. Jack',
#   'Claudia H. Kawas',
#   'William E. Klunk',
#   'Walter J. Koroshetz',
#   'Jennifer J. Manly',
#   'Richard Mayeux',
#   'Richard C. Mohs',
#   'John C. Morris',
#   'Martin N. Rossor',
#   'Philip Scheltens',
#   'María C. Carrillo',
#   'Bill Thies',
#   'Sandra Weıntraub',
#   'Creighton H. Phelps'],
#  'David S. Knopman': ['Guy M. McKhann',
#   'Howard Chertkow',
#   'Bradley T. Hyman',
#   'Clifford R. Jack',
#   'Claudia H. Kawas',
#   'William E. Klunk',
#   'Walter J. Koroshetz',
#   'Jennifer J. Manly',
#   'Richard Mayeux',
#   'Richard C. Mohs',
#   'John C. Morris',
#   'Martin N. Rossor',
#   'Philip Scheltens',
#   'María C. Carrillo',
#   'Bill Thies',
#   'Sandra Weıntraub',
#   'Creighton H. Phelps'],
#  'Howard Chertkow': ['Guy M. McKhann',
#   'David S. Knopman',
#   'Bradley T. Hyman',
#   'Clifford R. Jack',
#   'Claudia H. Kawas',
#   'William E. Klunk',
#   'Walter J. Koroshetz',
#   'Jennifer J. Manly',
#   'Richard Mayeux',
#   'Richard C. Mohs',
#   'John C. Morris',
#   'Martin N. Rossor',
#   'Philip Scheltens',
#   'María C. Carrillo',
#   'Bill Thies',
#   'Sandra Weıntraub',
#   'Creighton H. Phelps'],
#  'Bradley T. Hyman': ['Guy M. McKhann',
#   'David S. Knopman',
#   'Howard Chertkow',
#   'Clifford R. Jack',
#   'Claudia H. Kawas',
#   'William E. Klunk',
#   'Walter J. Koroshetz',
#   'Jennifer J. Manly',
#   'Richard Mayeux',
#   'Richard C. Mohs',
#   'John C. Morris',
#   'Martin N. Rossor',
#   'Philip Scheltens',
#   'María C. Carrillo',
#   'Bill Thies',
#   'Sandra Weıntraub',
#   'Creighton H. Phelps'],
#  'Clifford R. Jack': ['Guy M. McKhann',
#   'David S. Knopman',
#   'Howard Chertkow',
#   'Bradley T. Hyman',
#   'Claudia H. Kawas',
#   'William E. Klunk',
#   'Walter J. Koroshetz',
#   'Jennifer J. Manly',
#   'Richard Mayeux',
#   'Richard C. Mohs',
#   'John C. Morris',
#   'Martin N. Rossor',
#   'Philip Scheltens',
#   'María C. Carrillo',
#   'Bill Thies',
#   'Sandra Weıntraub',
#   'Creighton H. Phelps'],
#  'Claudia H. Kawas': ['Guy M. McKhann',
#   'David S. Knopman',
#   'Howard Chertkow',
#   'Bradley T. Hyman',
#   'Clifford R. Jack',
#   'William E. Klunk',
#   'Walter J. Koroshetz',
#   'Jennifer J. Manly',
#   'Richard Mayeux',
#   'Richard C. Mohs',
#   'John C. Morris',
#   'Martin N. Rossor',
#   'Philip Scheltens',
#   'María C. Carrillo',
#   'Bill Thies',
#   'Sandra Weıntraub',
#   'Creighton H. Phelps'],
#  'William E. Klunk': ['Guy M. McKhann',
#   'David S. Knopman',
#   'Howard Chertkow',
#   'Bradley T. Hyman',
#   'Clifford R. Jack',
#   'Claudia H. Kawas',
#   'Walter J. Koroshetz',
#   'Jennifer J. Manly',
#   'Richard Mayeux',
#   'Richard C. Mohs',
#   'John C. Morris',
#   'Martin N. Rossor',
#   'Philip Scheltens',
#   'María C. Carrillo',
#   'Bill Thies',
#   'Sandra Weıntraub',
#   'Creighton H. Phelps'],
#  'Walter J. Koroshetz': ['Guy M. McKhann',
#   'David S. Knopman',
#   'Howard Chertkow',
#   'Bradley T. Hyman',
#   'Clifford R. Jack',
#   'Claudia H. Kawas',
#   'William E. Klunk',
#   'Jennifer J. Manly',
#   'Richard Mayeux',
#   'Richard C. Mohs',
#   'John C. Morris',
#   'Martin N. Rossor',
#   'Philip Scheltens',
#   'María C. Carrillo',
#   'Bill Thies',
#   'Sandra Weıntraub',
#   'Creighton H. Phelps'],
#  'Jennifer J. Manly': ['Guy M. McKhann',
#   'David S. Knopman',
#   'Howard Chertkow',
#   'Bradley T. Hyman',
#   'Clifford R. Jack',
#   'Claudia H. Kawas',
#   'William E. Klunk',
#   'Walter J. Koroshetz',
#   'Richard Mayeux',
#   'Richard C. Mohs',
#   'John C. Morris',
#   'Martin N. Rossor',
#   'Philip Scheltens',
#   'María C. Carrillo',
#   'Bill Thies',
#   'Sandra Weıntraub',
#   'Creighton H. Phelps'],
#  'Richard Mayeux': ['Guy M. McKhann',
#   'David S. Knopman',
#   'Howard Chertkow',
#   'Bradley T. Hyman',
#   'Clifford R. Jack',
#   'Claudia H. Kawas',
#   'William E. Klunk',
#   'Walter J. Koroshetz',
#   'Jennifer J. Manly',
#   'Richard C. Mohs',
#   'John C. Morris',
#   'Martin N. Rossor',
#   'Philip Scheltens',
#   'María C. Carrillo',
#   'Bill Thies',
#   'Sandra Weıntraub',
#   'Creighton H. Phelps'],
#  'Richard C. Mohs': ['Guy M. McKhann',
#   'David S. Knopman',
#   'Howard Chertkow',
#   'Bradley T. Hyman',
#   'Clifford R. Jack',
#   'Claudia H. Kawas',
#   'William E. Klunk',
#   'Walter J. Koroshetz',
#   'Jennifer J. Manly',
#   'Richard Mayeux',
#   'John C. Morris',
#   'Martin N. Rossor',
#   'Philip Scheltens',
#   'María C. Carrillo',
#   'Bill Thies',
#   'Sandra Weıntraub',
#   'Creighton H. Phelps'],
#  'John C. Morris': ['Guy M. McKhann',
#   'David S. Knopman',
#   'Howard Chertkow',
#   'Bradley T. Hyman',
#   'Clifford R. Jack',
#   'Claudia H. Kawas',
#   'William E. Klunk',
#   'Walter J. Koroshetz',
#   'Jennifer J. Manly',
#   'Richard Mayeux',
#   'Richard C. Mohs',
#   'Martin N. Rossor',
#   'Philip Scheltens',
#   'María C. Carrillo',
#   'Bill Thies',
#   'Sandra Weıntraub',
#   'Creighton H. Phelps'],
#  'Martin N. Rossor': ['Guy M. McKhann',
#   'David S. Knopman',
#   'Howard Chertkow',
#   'Bradley T. Hyman',
#   'Clifford R. Jack',
#   'Claudia H. Kawas',
#   'William E. Klunk',
#   'Walter J. Koroshetz',
#   'Jennifer J. Manly',
#   'Richard Mayeux',
#   'Richard C. Mohs',
#   'John C. Morris',
#   'Philip Scheltens',
#   'María C. Carrillo',
#   'Bill Thies',
#   'Sandra Weıntraub',
#   'Creighton H. Phelps'],
#  'Philip Scheltens': ['Guy M. McKhann',
#   'David S. Knopman',
#   'Howard Chertkow',
#   'Bradley T. Hyman',
#   'Clifford R. Jack',
#   'Claudia H. Kawas',
#   'William E. Klunk',
#   'Walter J. Koroshetz',
#   'Jennifer J. Manly',
#   'Richard Mayeux',
#   'Richard C. Mohs',
#   'John C. Morris',
#   'Martin N. Rossor',
#   'María C. Carrillo',
#   'Bill Thies',
#   'Sandra Weıntraub',
#   'Creighton H. Phelps'],
#  'María C. Carrillo': ['Guy M. McKhann',
#   'David S. Knopman',
#   'Howard Chertkow',
#   'Bradley T. Hyman',
#   'Clifford R. Jack',
#   'Claudia H. Kawas',
#   'William E. Klunk',
#   'Walter J. Koroshetz',
#   'Jennifer J. Manly',
#   'Richard Mayeux',
#   'Richard C. Mohs',
#   'John C. Morris',
#   'Martin N. Rossor',
#   'Philip Scheltens',
#   'Bill Thies',
#   'Sandra Weıntraub',
#   'Creighton H. Phelps'],
#  'Bill Thies': ['Guy M. McKhann',
#   'David S. Knopman',
#   'Howard Chertkow',
#   'Bradley T. Hyman',
#   'Clifford R. Jack',
#   'Claudia H. Kawas',
#   'William E. Klunk',
#   'Walter J. Koroshetz',
#   'Jennifer J. Manly',
#   'Richard Mayeux',
#   'Richard C. Mohs',
#   'John C. Morris',
#   'Martin N. Rossor',
#   'Philip Scheltens',
#   'María C. Carrillo',
#   'Sandra Weıntraub',
#   'Creighton H. Phelps'],
#  'Sandra Weıntraub': ['Guy M. McKhann',
#   'David S. Knopman',
#   'Howard Chertkow',
#   'Bradley T. Hyman',
#   'Clifford R. Jack',
#   'Claudia H. Kawas',
#   'William E. Klunk',
#   'Walter J. Koroshetz',
#   'Jennifer J. Manly',
#   'Richard Mayeux',
#   'Richard C. Mohs',
#   'John C. Morris',
#   'Martin N. Rossor',
#   'Philip Scheltens',
#   'María C. Carrillo',
#   'Bill Thies',
#   'Creighton H. Phelps'],
#  'Creighton H. Phelps': ['Guy M. McKhann',
#   'David S. Knopman',
#   'Howard Chertkow',
#   'Bradley T. Hyman',
#   'Clifford R. Jack',
#   'Claudia H. Kawas',
#   'William E. Klunk',
#   'Walter J. Koroshetz',
#   'Jennifer J. Manly',
#   'Richard Mayeux',
#   'Richard C. Mohs',
#   'John C. Morris',
#   'Martin N. Rossor',
#   'Philip Scheltens',
#   'María C. Carrillo',
#   'Bill Thies',
#   'Sandra Weıntraub'],
#  'Sasha Stankovich': ['Dmitriy A. Dikin',
#   'Eric Zimney',
#   'Richard D. Piner',
#   'Geoffrey Dommett',
#   'Guennadi Evmenenko',
#   'SonBinh T. Nguyen',
#   'Rodney S. Ruoff'],
#  'Dmitriy A. Dikin': ['Sasha Stankovich',
#   'Eric Zimney',
#   'Richard D. Piner',
#   'Geoffrey Dommett',
#   'Guennadi Evmenenko',
#   'SonBinh T. Nguyen',
#   'Rodney S. Ruoff'],
#  'Richard D. Piner': ['Dmitriy A. Dikin',
#   'Sasha Stankovich',
#   'Eric Zimney',
#   'Geoffrey Dommett',
#   'Guennadi Evmenenko',
#   'SonBinh T. Nguyen',
#   'Rodney S. Ruoff'],
#  'Kevin A. Kohlhaas': ['Sasha Stankovich',
#   'Dmitriy A. Dikin',
#   'Richard D. Piner',
#   'Alfred Kleinhammes',
#   'Yuanyuan Jia',
#   'Yue Wu',
#   'SonBinh T. Nguyen',
#   'Rodney S. Ruoff'],
#  'Alfred Kleinhammes': ['Sasha Stankovich',
#   'Dmitriy A. Dikin',
#   'Richard D. Piner',
#   'Kevin A. Kohlhaas',
#   'Yuanyuan Jia',
#   'Yue Wu',
#   'SonBinh T. Nguyen',
#   'Rodney S. Ruoff'],
#  'Yuanyuan Jia': ['Sasha Stankovich',
#   'Dmitriy A. Dikin',
#   'Richard D. Piner',
#   'Kevin A. Kohlhaas',
#   'Alfred Kleinhammes',
#   'Yue Wu',
#   'SonBinh T. Nguyen',
#   'Rodney S. Ruoff'],
#  'Yue Wu': ['Sasha Stankovich',
#   'Dmitriy A. Dikin',
#   'Richard D. Piner',
#   'Kevin A. Kohlhaas',
#   'Alfred Kleinhammes',
#   'Yuanyuan Jia',
#   'SonBinh T. Nguyen',
#   'Rodney S. Ruoff'],
#  'SonBinh T. Nguyen': ['Dmitriy A. Dikin',
#   'Sasha Stankovich',
#   'Eric Zimney',
#   'Richard D. Piner',
#   'Geoffrey Dommett',
#   'Guennadi Evmenenko',
#   'Rodney S. Ruoff'],
#  'Rodney S. Ruoff': ['Dmitriy A. Dikin',
#   'Sasha Stankovich',
#   'Eric Zimney',
#   'Richard D. Piner',
#   'Geoffrey Dommett',
#   'Guennadi Evmenenko',
#   'SonBinh T. Nguyen'],
#  'Geoffrey Dommett': ['Dmitriy A. Dikin',
#   'Sasha Stankovich',
#   'Eric Zimney',
#   'Richard D. Piner',
#   'Guennadi Evmenenko',
#   'SonBinh T. Nguyen',
#   'Rodney S. Ruoff'],
#  'K. Kohlhaas': ['Sasha Stankovich',
#   'Dmitriy A. Dikin',
#   'Geoffrey Dommett',
#   'Eric Zimney',
#   'Eric A. Stach',
#   'Richard D. Piner',
#   'SonBinh T. Nguyen',
#   'Rodney S. Ruoff'],
#  'Eric Zimney': ['Dmitriy A. Dikin',
#   'Sasha Stankovich',
#   'Richard D. Piner',
#   'Geoffrey Dommett',
#   'Guennadi Evmenenko',
#   'SonBinh T. Nguyen',
#   'Rodney S. Ruoff'],
#  'Eric A. Stach': ['Sasha Stankovich',
#   'Dmitriy A. Dikin',
#   'Geoffrey Dommett',
#   'K. Kohlhaas',
#   'Eric Zimney',
#   'Richard D. Piner',
#   'SonBinh T. Nguyen',
#   'Rodney S. Ruoff'],
#  'Robert M. Entman': [],
#  'Saul B. Needleman': ['Christian D. Wunsch'],
#  'Christian D. Wunsch': ['Saul B. Needleman'],
#  'Margaret A. Peteraf': [],
#  'K. Lance Kelly': ['Eduardo A. Coronado', 'Linlin Zhao', 'George C. Schatz'],
#  'Eduardo A. Coronado': ['K. Lance Kelly', 'Linlin Zhao', 'George C. Schatz'],
#  'Linlin Zhao': ['K. Lance Kelly', 'Eduardo A. Coronado', 'George C. Schatz'],
#  'George C. Schatz': ['K. Lance Kelly', 'Eduardo A. Coronado', 'Linlin Zhao'],
#  'Haeshin Lee': ['Shara M. Dellatore',
#   'William M. Miller',
#   'Phillip B. Messersmith'],
#  'Shara M. Dellatore': ['Haeshin Lee',
#   'William M. Miller',
#   'Phillip B. Messersmith'],
#  'William M. Miller': ['Haeshin Lee',
#   'Shara M. Dellatore',
#   'Phillip B. Messersmith'],
#  'Phillip B. Messersmith': ['Haeshin Lee',
#   'Shara M. Dellatore',
#   'William M. Miller'],
#  'Jun Young Lee': ['Omar K. Farha',
#   'John M. Roberts',
#   'Karl A. Scheidt',
#   'SonBinh T. Nguyen',
#   'Joseph T. Hupp'],
#  'Omar K. Farha': ['Lauren E. Kreno',
#   'Kirsty Leong',
#   'Mark D. Allendorf',
#   'Richard P. Van Duyne',
#   'Joseph T. Hupp'],
#  'John M. Roberts': ['Jun Young Lee',
#   'Omar K. Farha',
#   'Karl A. Scheidt',
#   'SonBinh T. Nguyen',
#   'Joseph T. Hupp'],
#  'Karl A. Scheidt': ['Jun Young Lee',
#   'Omar K. Farha',
#   'John M. Roberts',
#   'SonBinh T. Nguyen',
#   'Joseph T. Hupp'],
#  'Joseph T. Hupp': ['Lauren E. Kreno',
#   'Kirsty Leong',
#   'Omar K. Farha',
#   'Mark D. Allendorf',
#   'Richard P. Van Duyne'],
#  'Albert László Barabási': ['Zoltán N. Oltvai'],
#  'Zoltán N. Oltvai': ['Albert László Barabási'],
#  'Chad A. Mirkin': ['Robert L. Letsinger',
#   'Robert C. Mucic',
#   'James J. Storhoff'],
#  'Robert L. Letsinger': ['Chad A. Mirkin',
#   'Robert C. Mucic',
#   'James J. Storhoff'],
#  'Robert C. Mucic': ['Chad A. Mirkin',
#   'Robert L. Letsinger',
#   'James J. Storhoff'],
#  'James J. Storhoff': ['Chad A. Mirkin',
#   'Robert L. Letsinger',
#   'Robert C. Mucic'],
#  'Cheng-Di Dong': ['Jorge Nocedal'],
#  'Jorge Nocedal': ['Cheng-Di Dong'],
#  'Lauren E. Kreno': ['Kirsty Leong',
#   'Omar K. Farha',
#   'Mark D. Allendorf',
#   'Richard P. Van Duyne',
#   'Joseph T. Hupp'],
#  'Kirsty Leong': ['Lauren E. Kreno',
#   'Omar K. Farha',
#   'Mark D. Allendorf',
#   'Richard P. Van Duyne',
#   'Joseph T. Hupp'],
#  'Mark D. Allendorf': ['Lauren E. Kreno',
#   'Kirsty Leong',
#   'Omar K. Farha',
#   'Richard P. Van Duyne',
#   'Joseph T. Hupp'],
#  'Richard P. Van Duyne': ['Katherine A. Willets'],
#  'Jeffrey N. Anker': ['W. Paige Hall',
#   'Olga Lyandres',
#   'Nilam C. Shah',
#   'Jing Zhao',
#   'Richard P. Van Duyne'],
#  'W. Paige Hall': ['Jeffrey N. Anker',
#   'Olga Lyandres',
#   'Nilam C. Shah',
#   'Jing Zhao',
#   'Richard P. Van Duyne'],
#  'Olga Lyandres': ['Jeffrey N. Anker',
#   'W. Paige Hall',
#   'Nilam C. Shah',
#   'Jing Zhao',
#   'Richard P. Van Duyne'],
#  'Nilam C. Shah': ['Jeffrey N. Anker',
#   'W. Paige Hall',
#   'Olga Lyandres',
#   'Jing Zhao',
#   'Richard P. Van Duyne'],
#  'Jing Zhao': ['Jeffrey N. Anker',
#   'W. Paige Hall',
#   'Olga Lyandres',
#   'Nilam C. Shah',
#   'Richard P. Van Duyne'],
#  'Xiang Wan': ['Wenqian Wang', 'Jiming Liu', 'Tiejun Tong'],
#  'Wenqian Wang': ['Xiang Wan', 'Jiming Liu', 'Tiejun Tong'],
#  'Jiming Liu': ['Xiang Wan', 'Wenqian Wang', 'Tiejun Tong'],
#  'Tiejun Tong': ['Xiang Wan', 'Wenqian Wang', 'Jiming Liu'],
#  'Roger B. Myerson': [],
#  'Rolf W. Banz': [],
#  'Lionel A. Mandell': ['Richard G. Wunderink',
#   'Antonio Anzueto',
#   'John G. Bartlett',
#   'G. Douglas Campbell',
#   'Nathan C. Dean',
#   'Scott F. Dowell',
#   'Daniel M. Musher',
#   'Michael S. Niederman',
#   'Antônio Torres',
#   'Cynthia G. Whitney',
#   'Michael E. DeBakey Veterans'],
#  'Richard G. Wunderink': ['Lionel A. Mandell',
#   'Antonio Anzueto',
#   'John G. Bartlett',
#   'G. Douglas Campbell',
#   'Nathan C. Dean',
#   'Scott F. Dowell',
#   'Daniel M. Musher',
#   'Michael S. Niederman',
#   'Antônio Torres',
#   'Cynthia G. Whitney',
#   'Michael E. DeBakey Veterans'],
#  'Antonio Anzueto': ['Lionel A. Mandell',
#   'Richard G. Wunderink',
#   'John G. Bartlett',
#   'G. Douglas Campbell',
#   'Nathan C. Dean',
#   'Scott F. Dowell',
#   'Daniel M. Musher',
#   'Michael S. Niederman',
#   'Antônio Torres',
#   'Cynthia G. Whitney',
#   'Michael E. DeBakey Veterans'],
#  'John G. Bartlett': ['Lionel A. Mandell',
#   'Richard G. Wunderink',
#   'Antonio Anzueto',
#   'G. Douglas Campbell',
#   'Nathan C. Dean',
#   'Scott F. Dowell',
#   'Daniel M. Musher',
#   'Michael S. Niederman',
#   'Antônio Torres',
#   'Cynthia G. Whitney',
#   'Michael E. DeBakey Veterans'],
#  'G. Douglas Campbell': ['Lionel A. Mandell',
#   'Richard G. Wunderink',
#   'Antonio Anzueto',
#   'John G. Bartlett',
#   'Nathan C. Dean',
#   'Scott F. Dowell',
#   'Daniel M. Musher',
#   'Michael S. Niederman',
#   'Antônio Torres',
#   'Cynthia G. Whitney',
#   'Michael E. DeBakey Veterans'],
#  'Nathan C. Dean': ['Lionel A. Mandell',
#   'Richard G. Wunderink',
#   'Antonio Anzueto',
#   'John G. Bartlett',
#   'G. Douglas Campbell',
#   'Scott F. Dowell',
#   'Daniel M. Musher',
#   'Michael S. Niederman',
#   'Antônio Torres',
#   'Cynthia G. Whitney',
#   'Michael E. DeBakey Veterans'],
#  'Scott F. Dowell': ['Lionel A. Mandell',
#   'Richard G. Wunderink',
#   'Antonio Anzueto',
#   'John G. Bartlett',
#   'G. Douglas Campbell',
#   'Nathan C. Dean',
#   'Daniel M. Musher',
#   'Michael S. Niederman',
#   'Antônio Torres',
#   'Cynthia G. Whitney',
#   'Michael E. DeBakey Veterans'],
#  'Daniel M. Musher': ['Lionel A. Mandell',
#   'Richard G. Wunderink',
#   'Antonio Anzueto',
#   'John G. Bartlett',
#   'G. Douglas Campbell',
#   'Nathan C. Dean',
#   'Scott F. Dowell',
#   'Michael S. Niederman',
#   'Antônio Torres',
#   'Cynthia G. Whitney',
#   'Michael E. DeBakey Veterans'],
#  'Michael S. Niederman': ['Lionel A. Mandell',
#   'Richard G. Wunderink',
#   'Antonio Anzueto',
#   'John G. Bartlett',
#   'G. Douglas Campbell',
#   'Nathan C. Dean',
#   'Scott F. Dowell',
#   'Daniel M. Musher',
#   'Antônio Torres',
#   'Cynthia G. Whitney',
#   'Michael E. DeBakey Veterans'],
#  'Antônio Torres': ['Lionel A. Mandell',
#   'Richard G. Wunderink',
#   'Antonio Anzueto',
#   'John G. Bartlett',
#   'G. Douglas Campbell',
#   'Nathan C. Dean',
#   'Scott F. Dowell',
#   'Daniel M. Musher',
#   'Michael S. Niederman',
#   'Cynthia G. Whitney',
#   'Michael E. DeBakey Veterans'],
#  'Cynthia G. Whitney': ['Lionel A. Mandell',
#   'Richard G. Wunderink',
#   'Antonio Anzueto',
#   'John G. Bartlett',
#   'G. Douglas Campbell',
#   'Nathan C. Dean',
#   'Scott F. Dowell',
#   'Daniel M. Musher',
#   'Michael S. Niederman',
#   'Antônio Torres',
#   'Michael E. DeBakey Veterans'],
#  'Michael E. DeBakey Veterans': ['Lionel A. Mandell',
#   'Richard G. Wunderink',
#   'Antonio Anzueto',
#   'John G. Bartlett',
#   'G. Douglas Campbell',
#   'Nathan C. Dean',
#   'Scott F. Dowell',
#   'Daniel M. Musher',
#   'Michael S. Niederman',
#   'Antônio Torres',
#   'Cynthia G. Whitney'],
#  'Katherine A. Willets': ['Richard P. Van Duyne'],
#  'Nicolas Moës': ['J Dolbow', 'Ted Belytschko'],
#  'J Dolbow': ['Nicolas Moës', 'Ted Belytschko'],
#  'Ted Belytschko': ['Ye Lu', 'Linxia Gu'],
#  'Guennadi Evmenenko': ['Dmitriy A. Dikin',
#   'Sasha Stankovich',
#   'Eric Zimney',
#   'Richard D. Piner',
#   'Geoffrey Dommett',
#   'SonBinh T. Nguyen',
#   'Rodney S. Ruoff'],
#  'Martien A. Cohen Stuart': ['Wilhelm T. S. Huck',
#   'Jan Genzer',
#   'Marcus Müller',
#   'Christopher K. Ober',
#   'Manfred Stamm',
#   'Gleb B. Sukhorukov',
#   'Igal Szleifer',
#   'Vladimir V. Tsukruk',
#   'Marek W. Urban',
#   'Françoise M. Winnik',
#   'Stefan Zauscher',
#   'Igor Luzinov',
#   'Sergiy Minko'],
#  'Wilhelm T. S. Huck': ['Martien A. Cohen Stuart',
#   'Jan Genzer',
#   'Marcus Müller',
#   'Christopher K. Ober',
#   'Manfred Stamm',
#   'Gleb B. Sukhorukov',
#   'Igal Szleifer',
#   'Vladimir V. Tsukruk',
#   'Marek W. Urban',
#   'Françoise M. Winnik',
#   'Stefan Zauscher',
#   'Igor Luzinov',
#   'Sergiy Minko'],
#  'Jan Genzer': ['Martien A. Cohen Stuart',
#   'Wilhelm T. S. Huck',
#   'Marcus Müller',
#   'Christopher K. Ober',
#   'Manfred Stamm',
#   'Gleb B. Sukhorukov',
#   'Igal Szleifer',
#   'Vladimir V. Tsukruk',
#   'Marek W. Urban',
#   'Françoise M. Winnik',
#   'Stefan Zauscher',
#   'Igor Luzinov',
#   'Sergiy Minko'],
#  'Marcus Müller': ['Martien A. Cohen Stuart',
#   'Wilhelm T. S. Huck',
#   'Jan Genzer',
#   'Christopher K. Ober',
#   'Manfred Stamm',
#   'Gleb B. Sukhorukov',
#   'Igal Szleifer',
#   'Vladimir V. Tsukruk',
#   'Marek W. Urban',
#   'Françoise M. Winnik',
#   'Stefan Zauscher',
#   'Igor Luzinov',
#   'Sergiy Minko'],
#  'Christopher K. Ober': ['Martien A. Cohen Stuart',
#   'Wilhelm T. S. Huck',
#   'Jan Genzer',
#   'Marcus Müller',
#   'Manfred Stamm',
#   'Gleb B. Sukhorukov',
#   'Igal Szleifer',
#   'Vladimir V. Tsukruk',
#   'Marek W. Urban',
#   'Françoise M. Winnik',
#   'Stefan Zauscher',
#   'Igor Luzinov',
#   'Sergiy Minko'],
#  'Manfred Stamm': ['Martien A. Cohen Stuart',
#   'Wilhelm T. S. Huck',
#   'Jan Genzer',
#   'Marcus Müller',
#   'Christopher K. Ober',
#   'Gleb B. Sukhorukov',
#   'Igal Szleifer',
#   'Vladimir V. Tsukruk',
#   'Marek W. Urban',
#   'Françoise M. Winnik',
#   'Stefan Zauscher',
#   'Igor Luzinov',
#   'Sergiy Minko'],
#  'Gleb B. Sukhorukov': ['Martien A. Cohen Stuart',
#   'Wilhelm T. S. Huck',
#   'Jan Genzer',
#   'Marcus Müller',
#   'Christopher K. Ober',
#   'Manfred Stamm',
#   'Igal Szleifer',
#   'Vladimir V. Tsukruk',
#   'Marek W. Urban',
#   'Françoise M. Winnik',
#   'Stefan Zauscher',
#   'Igor Luzinov',
#   'Sergiy Minko'],
#  'Igal Szleifer': ['Martien A. Cohen Stuart',
#   'Wilhelm T. S. Huck',
#   'Jan Genzer',
#   'Marcus Müller',
#   'Christopher K. Ober',
#   'Manfred Stamm',
#   'Gleb B. Sukhorukov',
#   'Vladimir V. Tsukruk',
#   'Marek W. Urban',
#   'Françoise M. Winnik',
#   'Stefan Zauscher',
#   'Igor Luzinov',
#   'Sergiy Minko'],
#  'Vladimir V. Tsukruk': ['Martien A. Cohen Stuart',
#   'Wilhelm T. S. Huck',
#   'Jan Genzer',
#   'Marcus Müller',
#   'Christopher K. Ober',
#   'Manfred Stamm',
#   'Gleb B. Sukhorukov',
#   'Igal Szleifer',
#   'Marek W. Urban',
#   'Françoise M. Winnik',
#   'Stefan Zauscher',
#   'Igor Luzinov',
#   'Sergiy Minko'],
#  'Marek W. Urban': ['Martien A. Cohen Stuart',
#   'Wilhelm T. S. Huck',
#   'Jan Genzer',
#   'Marcus Müller',
#   'Christopher K. Ober',
#   'Manfred Stamm',
#   'Gleb B. Sukhorukov',
#   'Igal Szleifer',
#   'Vladimir V. Tsukruk',
#   'Françoise M. Winnik',
#   'Stefan Zauscher',
#   'Igor Luzinov',
#   'Sergiy Minko'],
#  'Françoise M. Winnik': ['Martien A. Cohen Stuart',
#   'Wilhelm T. S. Huck',
#   'Jan Genzer',
#   'Marcus Müller',
#   'Christopher K. Ober',
#   'Manfred Stamm',
#   'Gleb B. Sukhorukov',
#   'Igal Szleifer',
#   'Vladimir V. Tsukruk',
#   'Marek W. Urban',
#   'Stefan Zauscher',
#   'Igor Luzinov',
#   'Sergiy Minko'],
#  'Stefan Zauscher': ['Martien A. Cohen Stuart',
#   'Wilhelm T. S. Huck',
#   'Jan Genzer',
#   'Marcus Müller',
#   'Christopher K. Ober',
#   'Manfred Stamm',
#   'Gleb B. Sukhorukov',
#   'Igal Szleifer',
#   'Vladimir V. Tsukruk',
#   'Marek W. Urban',
#   'Françoise M. Winnik',
#   'Igor Luzinov',
#   'Sergiy Minko'],
#  'Igor Luzinov': ['Martien A. Cohen Stuart',
#   'Wilhelm T. S. Huck',
#   'Jan Genzer',
#   'Marcus Müller',
#   'Christopher K. Ober',
#   'Manfred Stamm',
#   'Gleb B. Sukhorukov',
#   'Igal Szleifer',
#   'Vladimir V. Tsukruk',
#   'Marek W. Urban',
#   'Françoise M. Winnik',
#   'Stefan Zauscher',
#   'Sergiy Minko'],
#  'Sergiy Minko': ['Martien A. Cohen Stuart',
#   'Wilhelm T. S. Huck',
#   'Jan Genzer',
#   'Marcus Müller',
#   'Christopher K. Ober',
#   'Manfred Stamm',
#   'Gleb B. Sukhorukov',
#   'Igal Szleifer',
#   'Vladimir V. Tsukruk',
#   'Marek W. Urban',
#   'Françoise M. Winnik',
#   'Stefan Zauscher',
#   'Igor Luzinov'],
#  'Ye Lu': ['Ted Belytschko', 'Linxia Gu'],
#  'Linxia Gu': ['Ted Belytschko', 'Ye Lu'],
#  'E. Allan Lind': ['Tom R. Tyler'],
#  'Tom R. Tyler': ['E. Allan Lind'],
#  'Andrew Ortony': ['Gerald L. Clore', 'Allan Collins'],
#  'Gerald L. Clore': ['Andrew Ortony', 'Allan Collins'],
#  'Allan Collins': ['Andrew Ortony', 'Gerald L. Clore']}

# %%
add_data_to_graph()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 add_data_to_graph()
#
# TypeError: add_data_to_graph() missing 2 required positional arguments: 'graph' and 'data'

# %%
kelsey = get_data('https://api.openalex.org/works/W2899966731')
kelsey_2= get_data('https://api.openalex.org/works/W3176337531')

# %%
graph = {}

for authorship in kelsey['authorships']:
    author = authorship['author']['display_name']
    graph[author] = []
    for other_authorship in kelsey['authorships']:
        other_author = other_authorship['author']['display_name']
        if other_author != author:
            graph[author].append(other_author)

graph
# Out:
# {'Gregory E. Miller': ['Eric Chen',
#   'Casey C. Armstrong',
#   'Ann Carroll',
#   'Sekine Ozturk',
#   'Kelsey Rydland',
#   'Gene H. Brody',
#   'Todd B. Parrish',
#   'Robin Nusslock'],
#  'Eric Chen': ['Gregory E. Miller',
#   'Casey C. Armstrong',
#   'Ann Carroll',
#   'Sekine Ozturk',
#   'Kelsey Rydland',
#   'Gene H. Brody',
#   'Todd B. Parrish',
#   'Robin Nusslock'],
#  'Casey C. Armstrong': ['Gregory E. Miller',
#   'Eric Chen',
#   'Ann Carroll',
#   'Sekine Ozturk',
#   'Kelsey Rydland',
#   'Gene H. Brody',
#   'Todd B. Parrish',
#   'Robin Nusslock'],
#  'Ann Carroll': ['Gregory E. Miller',
#   'Eric Chen',
#   'Casey C. Armstrong',
#   'Sekine Ozturk',
#   'Kelsey Rydland',
#   'Gene H. Brody',
#   'Todd B. Parrish',
#   'Robin Nusslock'],
#  'Sekine Ozturk': ['Gregory E. Miller',
#   'Eric Chen',
#   'Casey C. Armstrong',
#   'Ann Carroll',
#   'Kelsey Rydland',
#   'Gene H. Brody',
#   'Todd B. Parrish',
#   'Robin Nusslock'],
#  'Kelsey Rydland': ['Gregory E. Miller',
#   'Eric Chen',
#   'Casey C. Armstrong',
#   'Ann Carroll',
#   'Sekine Ozturk',
#   'Gene H. Brody',
#   'Todd B. Parrish',
#   'Robin Nusslock'],
#  'Gene H. Brody': ['Gregory E. Miller',
#   'Eric Chen',
#   'Casey C. Armstrong',
#   'Ann Carroll',
#   'Sekine Ozturk',
#   'Kelsey Rydland',
#   'Todd B. Parrish',
#   'Robin Nusslock'],
#  'Todd B. Parrish': ['Gregory E. Miller',
#   'Eric Chen',
#   'Casey C. Armstrong',
#   'Ann Carroll',
#   'Sekine Ozturk',
#   'Kelsey Rydland',
#   'Gene H. Brody',
#   'Robin Nusslock'],
#  'Robin Nusslock': ['Gregory E. Miller',
#   'Eric Chen',
#   'Casey C. Armstrong',
#   'Ann Carroll',
#   'Sekine Ozturk',
#   'Kelsey Rydland',
#   'Gene H. Brody',
#   'Todd B. Parrish']}

# %%
for authorship in kelsey_2['authorships']:
    author = authorship['author']['display_name']
    graph[author] = []
    for other_authorship in kelsey_2['authorships']:
        other_author = other_authorship['author']['display_name']
        if other_author != author:
            graph[author].append(other_author)

graph
# Out:
# {'Gregory E. Miller': ['Eric Chen',
#   'Casey C. Armstrong',
#   'Ann Carroll',
#   'Sekine Ozturk',
#   'Kelsey Rydland',
#   'Gene H. Brody',
#   'Todd B. Parrish',
#   'Robin Nusslock'],
#  'Eric Chen': ['Gregory E. Miller',
#   'Casey C. Armstrong',
#   'Ann Carroll',
#   'Sekine Ozturk',
#   'Kelsey Rydland',
#   'Gene H. Brody',
#   'Todd B. Parrish',
#   'Robin Nusslock'],
#  'Casey C. Armstrong': ['Gregory E. Miller',
#   'Eric Chen',
#   'Ann Carroll',
#   'Sekine Ozturk',
#   'Kelsey Rydland',
#   'Gene H. Brody',
#   'Todd B. Parrish',
#   'Robin Nusslock'],
#  'Ann Carroll': ['Gregory E. Miller',
#   'Eric Chen',
#   'Casey C. Armstrong',
#   'Sekine Ozturk',
#   'Kelsey Rydland',
#   'Gene H. Brody',
#   'Todd B. Parrish',
#   'Robin Nusslock'],
#  'Sekine Ozturk': ['Gregory E. Miller',
#   'Eric Chen',
#   'Casey C. Armstrong',
#   'Ann Carroll',
#   'Kelsey Rydland',
#   'Gene H. Brody',
#   'Todd B. Parrish',
#   'Robin Nusslock'],
#  'Kelsey Rydland': ['Thanh Huyen T. Vu',
#   'Chad J. Achenbach',
#   'Linda Van Horn',
#   'Marilyn C. Cornelis'],
#  'Gene H. Brody': ['Gregory E. Miller',
#   'Eric Chen',
#   'Casey C. Armstrong',
#   'Ann Carroll',
#   'Sekine Ozturk',
#   'Kelsey Rydland',
#   'Todd B. Parrish',
#   'Robin Nusslock'],
#  'Todd B. Parrish': ['Gregory E. Miller',
#   'Eric Chen',
#   'Casey C. Armstrong',
#   'Ann Carroll',
#   'Sekine Ozturk',
#   'Kelsey Rydland',
#   'Gene H. Brody',
#   'Robin Nusslock'],
#  'Robin Nusslock': ['Gregory E. Miller',
#   'Eric Chen',
#   'Casey C. Armstrong',
#   'Ann Carroll',
#   'Sekine Ozturk',
#   'Kelsey Rydland',
#   'Gene H. Brody',
#   'Todd B. Parrish'],
#  'Thanh Huyen T. Vu': ['Kelsey Rydland',
#   'Chad J. Achenbach',
#   'Linda Van Horn',
#   'Marilyn C. Cornelis'],
#  'Chad J. Achenbach': ['Thanh Huyen T. Vu',
#   'Kelsey Rydland',
#   'Linda Van Horn',
#   'Marilyn C. Cornelis'],
#  'Linda Van Horn': ['Thanh Huyen T. Vu',
#   'Kelsey Rydland',
#   'Chad J. Achenbach',
#   'Marilyn C. Cornelis'],
#  'Marilyn C. Cornelis': ['Thanh Huyen T. Vu',
#   'Kelsey Rydland',
#   'Chad J. Achenbach',
#   'Linda Van Horn']}

# %%
# Visualize the graph
import networkx as nx
import matplotlib.pyplot as plt
import nbformat

G = nx.Graph(graph)
pos = nx.spring_layout(G)

edge_x = []
edge_y = []
for edge in G.edges():
    x0, y0 = pos[edge[0]]
    x1, y1 = pos[edge[1]]
    edge_x.extend([x0, x1, None])
    edge_y.extend([y0, y1, None])

edge_trace = go.Scatter(x=edge_x, y=edge_y, line=dict(width=0.5, color='#888'), hoverinfo='none', mode='lines')

node_x = [pos[node][0] for node in G.nodes()]
node_y = [pos[node][1] for node in G.nodes()]

# Add text to each node
node_text = [f'Node {node}' for node in G.nodes()]

# Add node colors that scale to number of connections
node_adjacencies = []
node_color = []
for node, adjacencies in enumerate(G.adjacency()):
    node_adjacencies.append(len(adjacencies[1]))
node_color = node_adjacencies

node_trace = go.Scatter(x=node_x, y=node_y, mode='markers', hoverinfo='text', marker=dict(showscale=True, colorscale='YlGnBu', size=10, color=node_color, line=dict(width=2)), text=node_text)

fig = go.Figure(data=[edge_trace, node_trace], layout=go.Layout(showlegend=False, hovermode='closest', margin=dict(b=20,l=5,r=5,t=40), xaxis=dict(showgrid=False, zeroline=False, showticklabels=False), yaxis=dict(showgrid=False, zeroline=False, showticklabels=False)))

fig.show()

# %%
# Find outliers in the graph
degree = dict(G.degree())
sorted_degree = sorted(degree.items(), key=lambda x: x[1], reverse=True)
print(sorted_degree)

# Find the most connected node
max_degree = max(degree, key=degree.get)
print(max_degree)
# Out:
# [('Guy M. McKhann', 17), ('David S. Knopman', 17), ('Howard Chertkow', 17), ('Bradley T. Hyman', 17), ('Clifford R. Jack', 17), ('Claudia H. Kawas', 17), ('William E. Klunk', 17), ('Walter J. Koroshetz', 17), ('Jennifer J. Manly', 17), ('Richard Mayeux', 17), ('Richard C. Mohs', 17), ('John C. Morris', 17), ('Martin N. Rossor', 17), ('Philip Scheltens', 17), ('María C. Carrillo', 17), ('Bill Thies', 17), ('Sandra Weıntraub', 17), ('Creighton H. Phelps', 17), ('SonBinh T. Nguyen', 16), ('Sasha Stankovich', 13), ('Dmitriy A. Dikin', 13), ('Richard D. Piner', 13), ('Rodney S. Ruoff', 13), ('Martien A. Cohen Stuart', 13), ('Wilhelm T. S. Huck', 13), ('Jan Genzer', 13), ('Marcus Müller', 13), ('Christopher K. Ober', 13), ('Manfred Stamm', 13), ('Gleb B. Sukhorukov', 13), ('Igal Szleifer', 13), ('Vladimir V. Tsukruk', 13), ('Marek W. Urban', 13), ('Françoise M. Winnik', 13), ('Stefan Zauscher', 13), ('Igor Luzinov', 13), ('Sergiy Minko', 13), ('Richard P. Van Duyne', 11), ('Lionel A. Mandell', 11), ('Richard G. Wunderink', 11), ('Antonio Anzueto', 11), ('John G. Bartlett', 11), ('G. Douglas Campbell', 11), ('Nathan C. Dean', 11), ('Scott F. Dowell', 11), ('Daniel M. Musher', 11), ('Michael S. Niederman', 11), ('Antônio Torres', 11), ('Cynthia G. Whitney', 11), ('Michael E. DeBakey Veterans', 11), ('Geoffrey Dommett', 9), ('Eric Zimney', 9), ('Kevin A. Kohlhaas', 8), ('Alfred Kleinhammes', 8), ('Yuanyuan Jia', 8), ('Yue Wu', 8), ('K. Kohlhaas', 8), ('Eric A. Stach', 8), ('Omar K. Farha', 8), ('Joseph T. Hupp', 8), ('Guennadi Evmenenko', 7), ('Jun Young Lee', 5), ('John M. Roberts', 5), ('Karl A. Scheidt', 5), ('Lauren E. Kreno', 5), ('Kirsty Leong', 5), ('Mark D. Allendorf', 5), ('Jeffrey N. Anker', 5), ('W. Paige Hall', 5), ('Olga Lyandres', 5), ('Nilam C. Shah', 5), ('Jing Zhao', 5), ('Ted Belytschko', 4), ('K. Lance Kelly', 3), ('Eduardo A. Coronado', 3), ('Linlin Zhao', 3), ('George C. Schatz', 3), ('Haeshin Lee', 3), ('Shara M. Dellatore', 3), ('William M. Miller', 3), ('Phillip B. Messersmith', 3), ('Chad A. Mirkin', 3), ('Robert L. Letsinger', 3), ('Robert C. Mucic', 3), ('James J. Storhoff', 3), ('Xiang Wan', 3), ('Wenqian Wang', 3), ('Jiming Liu', 3), ('Tiejun Tong', 3), ('Nicolas Moës', 2), ('J Dolbow', 2), ('Ye Lu', 2), ('Linxia Gu', 2), ('Andrew Ortony', 2), ('Gerald L. Clore', 2), ('Allan Collins', 2), ('Saul B. Needleman', 1), ('Christian D. Wunsch', 1), ('Albert László Barabási', 1), ('Zoltán N. Oltvai', 1), ('Cheng-Di Dong', 1), ('Jorge Nocedal', 1), ('Katherine A. Willets', 1), ('E. Allan Lind', 1), ('Tom R. Tyler', 1), ('Robert M. Entman', 0), ('Margaret A. Peteraf', 0), ('Roger B. Myerson', 0), ('Rolf W. Banz', 0)]
# Guy M. McKhann

# %%
import torch
from torch_geometric.nn import GCNConv
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import torch
# ----> 2 from torch_geometric.nn import GCNConv
#
# ModuleNotFoundError: No module named 'torch_geometric'

# %%
class GCN(torch.nn.Module):
    def __init__(self, num_features, num_classes):
        super(GCN, self).__init__()
        self.conv1 = GCNConv(num_features, 16)
        self.conv2 = GCNConv(16, num_classes)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index

        x = self.conv1(x, edge_index)
        x = torch.relu(x)
        x = torch.dropout(x, training=self.training)
        x = self.conv2(x, edge_index)

        return torch.log_softmax(x, dim=1)

# Instantiate the model
model = GCN(num_features, num_classes)

# Define a loss function
criterion = torch.nn.CrossEntropyLoss()

# Define an optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

# Training loop
for epoch in range(200):
    model.train()
    optimizer.zero_grad()
    out = model(data)
    loss = criterion(out[data.train_mask], data.y[data.train_mask])
    loss.backward()
    optimizer.step()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 18
#      15         return torch.log_softmax(x, dim=1)
#      17 # Instantiate the model
# ---> 18 model = GCN(num_features, num_classes)
#      20 # Define a loss function
#      21 criterion = torch.nn.CrossEntropyLoss()
#
# NameError: name 'num_features' is not defined
